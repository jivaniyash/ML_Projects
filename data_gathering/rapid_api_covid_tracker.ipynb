# %%
import requests
import pandas as pd
from rapid_api_key import api_key

# %%
url = "https://vaccovid-coronavirus-vaccine-and-treatment-tracker.p.rapidapi.com/api/npm-covid-data/"

headers = {
	"X-RapidAPI-Key": api_key,
	"X-RapidAPI-Host": "vaccovid-coronavirus-vaccine-and-treatment-tracker.p.rapidapi.com"
}
response = requests.get(url,headers=headers)
pd.DataFrame(response.json())
# Out:
#                                        id  rank           Country  \
# 0    63492a0f-56d7-4c00-9ac1-d64fd5414029     0            Total:
# 1    40f44943-8413-4a31-a4df-deee8111f85f     0             World
# 2    be02608d-a52f-4586-ae9b-220dee7daaf1     1               USA
# 3    f6ecf8d7-5867-42dc-9290-24fda4cb14f0     2             India
# 4    911f9162-c39d-4e1c-9768-4d147cce2604     3            France
# ..                                    ...   ...               ...
# 217  b230d5ca-c30a-4d22-814e-53ceccfb8364   224  Diamond Princess
# 218  f4fd07f5-e786-4153-bafe-7b35194a7eef   226      Vatican City
# 219  98a06a3a-311a-445f-9caf-3b967e1ffef5   228    Western Sahara
# 220  fa63e305-e10f-4b5d-a400-2edd6dcab0f4   229        MS Zaandam
# 221  eb9b3fbc-6738-4a35-a943-42a0e05ea149   230             China
#
#          Continent TwoLetterSymbol ThreeLetterSymbol  Infection_Risk  \
# 0              All            None              None            0.00
# 1              All            None              None            0.00
# 2    North America              us               usa           29.78
# 3             Asia              in               ind            3.18
# 4           Europe              fr               fra           56.43
# ..             ...             ...               ...             ...
# 217                             us               usa            0.00
# 218         Europe              va               vat            3.63
# 219         Africa              eh               esh            0.00
# 220                             us               usa            0.00
# 221           Asia              cn               chn            0.02
#
#      Case_Fatality_Rate  Test_Percentage  Recovery_Proporation  ...  \
# 0                  1.04             0.00                 96.84  ...
# 1                  1.04             0.00                 96.84  ...
# 2                  1.10           338.35                 97.58  ...
# 3                  1.19            64.13                 98.78  ...
# 4                  0.43           413.95                 97.97  ...
# ..                  ...              ...                   ...  ...
# 217                1.83             0.00                 98.17  ...
# 218                0.00             0.00                100.00  ...
# 219               10.00             0.00                 90.00  ...
# 220               22.22             0.00                 77.78  ...
# 221                1.96            11.05                 94.92  ...
#
#      ActiveCases  TotalTests  Population  one_Caseevery_X_ppl  \
# 0       13535705           0           0                    0
# 1       13535705           0           0                    0
# 2        1312257  1132805201   334805269                    3
# 3          13559   902104560  1406631776                   31
# 4         593593   271490188    65584518                    2
# ..           ...         ...         ...                  ...
# 217            0           0           0                    0
# 218            0           0         799                   28
# 219            0           0      626161                62616
# 220            0           0           0                    0
# 221         8313   160000000  1448471400                 5438
#
#     one_Deathevery_X_ppl  one_Testevery_X_ppl  Deaths_1M_pop Serious_Critical  \
# 0                      0                    0          847.8            35698
# 1                      0                    0          847.8            35698
# 2                    305                    0         3281.0             2622
# 3                   2651                    2          377.0              698
# 4                    416                    0         2402.0              869
# ..                   ...                  ...            ...              ...
# 217                    0                    0            0.0                0
# 218                    0                    0            0.0                0
# 219               626161                    0            2.0                0
# 220                    0                    0            0.0                0
# 221               277166                    9            4.0               27
#
#     Tests_1M_Pop  TotCases_1M_Pop
# 0              0          81905.5
# 1              0          81905.0
# 2        3383475         297779.0
# 3         641322          31752.0
# 4        4139547         564345.0
# ..           ...              ...
# 217            0              0.0
# 218            0          36295.0
# 219            0             16.0
# 220            0              0.0
# 221       110461            184.0
#
# [222 rows x 26 columns]
